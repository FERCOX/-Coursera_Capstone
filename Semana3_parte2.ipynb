# %% [markdown]
# Tarea Semana 3 parte 2

# %%
import pandas as pd 
import requests

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
df = df[0]
df.head()
# Out:
#                                                    0                1  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                                 2  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                                 3  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# 3                    M4EEast Toronto(The Beaches)
# 4                           M4GEast York(Leaside)
#
#                                                  4  \
# 0  M5ADowntown Toronto(Regent Park / Harbourfront)
# 1    M5BDowntown Toronto(Garden District, Ryerson)
# 2              M5CDowntown Toronto(St. James Town)
# 3                 M5EDowntown Toronto(Berczy Park)
# 4          M5GDowntown Toronto(Central Bay Street)
#
#                                                   5  \
# 0  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 1                          M6BNorth York(Glencairn)
# 2                       M6CYork(Humewood-Cedarvale)
# 3                      M6EYork(Caledonia-Fairbanks)
# 4                     M6GDowntown Toronto(Christie)
#
#                                                 6                7  \
# 0  M7AQueen's Park(Ontario Provincial Government)  M8ANot assigned
# 1                                 M7BNot assigned  M8BNot assigned
# 2                                 M7CNot assigned  M8CNot assigned
# 3                                 M7ENot assigned  M8ENot assigned
# 4                                 M7GNot assigned  M8GNot assigned
#
#                                                    8
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
code_list = df.values.tolist()

# %% [markdown]
# Guardo código postal que si esta asignado

# %%
postal_code =[]
borough = []
nb = []
for i in code_list:
    for j in i:
        if j[3:] == 'Not assigned':
            pass
        else:
            postal_code.append(j[0:3])
            sep = j[3:].split('(')
            borough.append(sep[0])
            nb.append(sep[1].split(')')[0])
data = {'Postal_Code':postal_code,'Borough':borough,'Neighborhood':nb}

# %% [markdown]
# Crear Data Frame

# %%
dfcp = pd.DataFrame(data)
dfcp.head()
# Out:
#   Postal_Code           Borough                       Neighborhood
# 0         M3A        North York                          Parkwoods
# 1         M4A        North York                   Victoria Village
# 2         M5A  Downtown Toronto         Regent Park / Harbourfront
# 3         M6A        North York  Lawrence Manor / Lawrence Heights
# 4         M7A      Queen's Park      Ontario Provincial Government

# %%
dfcp.shape
# Out:
# (103, 3)

# %%
# !pip install geocoder
import geocoder

# !pip install wget
import wget
# !wget -O toronto_coord.csv http://cocl.us/Geospatial_data 
df_coord = pd.read_csv('toronto_coord.csv')
print(df_coord.head())
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.38.1)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from geocoder) (2.26.0)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from geocoder) (8.0.3)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: importlib-metadata in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from click->geocoder) (4.8.2)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ratelim->geocoder) (5.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->geocoder) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->geocoder) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->geocoder) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->geocoder) (2.0.8)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata->click->geocoder) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata->click->geocoder) (3.6.0)
# Requirement already satisfied: wget in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (3.2)
# URL transformed to HTTPS due to an HSTS policy
# --2022-03-09 02:50:33--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 150.239.113.228, 150.239.82.32
# Connecting to cocl.us (cocl.us)|150.239.113.228|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2022-03-09 02:50:33--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2022-03-09 02:50:34--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2022-03-09 02:50:34--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.29.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.29.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!RWK0wg7A92SO3JRG7nvOoo6bZZ-KvvTLzZg_G3YCYh8-bXMWcZyxjbk5dqRVUU7GqncgJDv4DBE2adb7X1KzoYiswBf0_OY5vunWsfMTvCVsOhegPEQxKuTzsFSzXKLM-xnvgew-cWgb04C0wt9_a9Y2ovsKAp9Z3KCZO3jyngyEPwV3GzMdASNlScqPC5XM9tZtp7WJVMPS2C7gvgwDpUYyLTNQINjCk2_g9LkNiaWMWatxg3jg7g89V2VGJBfr5gfE_1vme6DS4uIyg7r_cBrYHBMEm1pier9AVl0Jv78glNZsiOOKAfz1ioZ956W8c9sKVAyj_ZNY_bpnfYtcW2Xty1MjBPz_yBaxWHSqUnE0bo7oEFtrXAzl0-mtXu6s_kIa2GjW6JxVuAGjwRZoYxm3eqEXr7tHh7dadUT2e36J_fmIsHQ4G4IeCyKKEr1QaDWWK8LbyrhM0499X164QhVO0pzZxvQc
Pz_yBaxWHSqUnE0bo7oEFtrXAzl0-mtXu6s_kIa2GjW6JxVuAGjwRZoYxm3eqEXr7tHh7dadUT2e36J_fmIsHQ4G4IeCyKKEr1QaDWWK8LbyrhM0499X164QhVO0pzZxvQcfsSvkj6HSaN9nwq9pLGILox1xtzV-Qj5xiQfZEAO_7RtJlGG2eRCt5ql2H9CNLmTsPTwitT_ThNrizTz7V_LLSdxLF2Lq3NE2puy6JrWuGQZT2c7i1N-4UMEgaW7PyIImHuzqEyWUXn54tlxo4_kbcrdrN0KgZnLso2jYfuffiyvtwaU6A8ujCHaoPOF_a_9X7_rWfUlzmUcQd0ya2Ed_V1iMAvUX6y7UakNvMvm3GjbqGSS49_tYsblS4nXuFj5swI4oFCbxB8VHO2fTly7ZI1GTmoFcmtgASbu8U2EfRnxTi8tTEViU2aPXzZ8MLdKdfDnlkFxzTgjy2tm1_IE1m3gfPEVsRPb-DyjlZcyJemcNcIogkNZbx15b2RnOMFpgXiHabdxhvIL-F6dqFen74XkGmrDyi9zLFKTDAMDG2lRR_WSrEhe_QMxWkFc9z6RJcydwiEJMsP87V7wXhtM658vQvD83EOLMH_D8ynC6bFvfTrAYMhhfr7Olf-vA6Gm_BNf2U3GAbwPoQq8UwERs3yN4qpmpOaWLTMzXYU9Semm2XXwXB59GOz8rQWZGOAcO1Je6t7fe-tnMDx2-C8IpnmLLcyTdGmZMeEJvZuNne3E5iWdaeewKDJDmmRC-4legg52D1jU0LECxO0zaakLBETZSMFaVY5CKZHmakv2amhe1rOE9ccfkmuXccVbxs7XWkky2V4Ojw-LMG0yOwVhTLP207L-9IkRD2r3KCH8-sv1rAd6HfBVAglvMOC7EWsaGdbLTqqXuBJz2iU3xEhcDtUZNpq-4U_yWJunXnQCiQfZ_iuVYnnzPsyKy87cS6ifHvp_uYubQZ2B6y-CqGeBlyhkvKxrbrQ-7tyAh5MmvKaod4_5QYGwXYmBwUIuvQyfWz1gJZFWajqnaKQ5T60E9-yjR3i6IJCB5Sz3XB8DTDq2-iCEdiEp07SgyA3C8ppQfxyEj2iNZVm2/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘toronto_coord.csv’
#
# toronto_coord.csv   100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2022-03-09 02:50:35 (99.4 MB/s) - ‘toronto_coord.csv’ saved [2891/2891]
#
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_coord.columns = ['Postal_Code','Latitude','Longitude']
df_coord.head()
# Out:
#   Postal_Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_total = pd.merge(dfcp,df_coord)
df_total.head()
# Out:
#   Postal_Code           Borough                       Neighborhood   Latitude  \
# 0         M3A        North York                          Parkwoods  43.753259
# 1         M4A        North York                   Victoria Village  43.725882
# 2         M5A  Downtown Toronto         Regent Park / Harbourfront  43.654260
# 3         M6A        North York  Lawrence Manor / Lawrence Heights  43.718518
# 4         M7A      Queen's Park      Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
